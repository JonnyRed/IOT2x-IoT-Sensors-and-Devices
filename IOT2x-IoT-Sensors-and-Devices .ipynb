# %%
from sympy import *
import numpy as np
import IPython.display as ipd
init_printing()

# %% [markdown]
# # IOT SENSORS AND DEVICES (IOT2X)
#
# 1. [Module1: Electrical circuits and electronics](#Module1:-Electrical-circuits-and-electronics)
# 2. [Module 2: End of the line things](#Module-2:-End-of-the-line-things)
#
#
# ----
#
# * [Course syllabus](IOT2x_Syllabus_T12018.pdf)
# * [Electronic Tutorials](https://www.electronics-tutorials.ws)
#
# Further resources
# * At SparkFun.com you can buy electronics materials and there are also excellent tutorials including;
#     * [What is Electricity](https://learn.sparkfun.com/tutorials/what-is-electricity)
#     * [What is a circuit](https://learn.sparkfun.com/tutorials/what-is-a-circuit)
#     * [What is Voltage](https://www.sparkfun.com/news/2207?_ga=2.140991538.1270140054.1523340763-657987938.1517896276)
#     * [What is current](https://www.sparkfun.com/news/2211?_ga=2.140991538.1270140054.1523340763-657987938.1517896276)
#     * [What is Electric power](https://learn.sparkfun.com/tutorials/electric-power?_ga=2.140457907.1270140054.1523340763-657987938.1517896276)
#
#
# * [JIMBO. n.d. “What is Electricity.” Sparkfun Electronics.](https://learn.sparkfun.com/tutorials/what-is-electricity)
# More information about semiconductor materials can be found in the following resource:
# * [Electronics Tutorials. n.d. “Semiconductor Basics.” Aspencore](https://www.electronics-tutorials.ws/diode/diode_1.html)
# * [Diodes](https://www.electronics-tutorials.ws/diode/diode_3.html)

# %% [markdown]
# # Module1: Electrical circuits and electronics

# %% [markdown]
# ## Basic IoT system
#
# ![Basic IoT system](BasicIoT-System.jpg "Basic IoT system")
#
# Types of Energy
#
# You may be surprised to know that there are not that many kinds of energy, only six as a matter of fact.
#
# Scientists classify energy as:
#
# * Mechanical
# * Chemical
# * Electrical
# * Radiant
# * Nuclear
# * Sound
#
#
# * Mechanical - people, windmills, moving gears
# * Chemical - burning wood, mixing baking soda and vinegar, heating packs
# * Electrical - BluRay players, stereos, washing machines
# * Radiant - the sun, light bulbs, X-rays
# * Nuclear - nuclear submarines, atomic bombs, nuclear reactor
# * Sound - musical instruments, voices, cat purring
#
#
# Jimb0. N.d. “[What is Electricity][1]?” Sparkfun Electronics.
#
# ![Resisistor Symbol](ResisistorSymbol.jpg 'Resisistor Symbol')
#
# How yo read a schematic [Video](https://youtu.be/_HZ-EQ8Hc8E)
#
#
# You may also find the following resources to be helpful in learning to read schematics.
#
# * Edraw. N.d. “[Standard Electrical Symbols For Electrical Schematic Diagrams][2].” EDraw.
# * JIMBO. N.d. “[How to Read a Schematic][3]”. Sparkfun electronics.
#
# And if you need to know more about fundamental electrical units, you may explore:
# * RapidTables. N.d. “[Electrical Units][4].” RapidTables.
#
# An electric circuit is an arrangement of components that performs a particular function by means of electricity.
#
# [4]:https://www.rapidtables.com/electric/Electric_units.html
# [3]:https://learn.sparkfun.com/tutorials/how-to-read-a-schematic
# [2]:https://www.edrawsoft.com/electrical-symbols.php
# [1]:https://learn.sparkfun.com/tutorials/what-is-electricity

# %%
W, V = 1000, 240
W,V
# Out:
# (1000, 240)

# %%
W/V
# Out:
# 4.166666666666667

# %% [markdown]
# ## Tinker with electricity in Tinkercad
#
# TinkerCad [video](https://youtu.be/HdHli3ZuIa0)

# %% [markdown]
# ## Ohm's Law activity using Tinkercad®
#
# |||
# |---|---|
# |[Ohm's Law activity using Tinkercad®](IOT2x_01_Ohm_s_Law.pdf)|![Ohms Law](OhmsLaw.jpg 'Ohms Law')|
#
# ## Series and Parallel Circuits
#
# |||
# |---|---|
# |[Series and Parallel Circuits](IOT2x_02_Series_and_Parallel_Circuits.pdf)|![Series and Parallel Circuit](Series-and-Parallel-Circuit.jpg 'Series and Parallel Circuit')|

# %% [markdown]
# ## Resistors, capacitors and inductors
#
# __Resistors__ are called __passive components__ because they do not need an external power supply to show their electric properties, nor do they produce any power. Other passive components are __Capacitors__ and __Inductors__
#
# Resistors, capacitors and inductors [Video](https://youtu.be/OEL5laB3hfU)

# %% [markdown]
# ## Semiconductors
#  n some materials, electrons are free to move and they are called conductors. Most metals are very good conductors.
#
# In other materials, electrons are not free to move and they are called insulators. Rubber and glass are examples of good insulators.
#
# Other materials are neither good conductors nor insulators; they are called semiconductors. You may think of semiconductors as materials that need a little help to become good conductors.
#
# With semiconductors, we need to apply a bit of external energy to get those electrons moving, turning the material into a conductor. But as soon as the external energy source is removed, the material goes back to its insulating state. The most common materials that present semiconductor properties are Silicon (Si) and Germanium (Ge).
#
# To make semiconductors useful - that is, to make it easy to control the amount of current flowing through them - they have to be ‘contaminated’ with other materials. These foreign ingredients are called dopants.
#
# Dopants are added to Silicon and Germanium to either increase or decrease the number of free electrons inside them.
#
# * If dopants give the material an excess of electrons, then it is called a negative (N-type) semiconductor.
# * If dopants produce a deficit of electrons, then the material is called a positive (P-type) semiconductor.
#
# Examples of common dopants are
# * Phosphorus for N-type, and
# * Boron For P-type semiconductors.

# %% [markdown]
# ## N-type and P-type semiconductors
#
# For the purpose of design and analysis, P-type semiconductors are considered to have an excess of holes (absence of electrons). The following diagrams represent in a graphical way N-type and P-type semiconductors.
#
# ![N-type and P-type semiconductors](SemiCond.jpg 'N-type and P-type semiconductors')
#
# What Is a semiconductor? [Video](https://youtu.be/gUmDVe6C-BU)

# %% [markdown]
# ## Diodes
#
# A diode is a 2-terminal device that is very good at conducting electricity in one direction only.
#
# It is made with one part N-type and one part P-type semiconductors. Its two terminals are called anode and cathode. Diodes become good conductors when the anode becomes more positive than the cathode by means of an external voltage supply.
#
# Structure and common symbols for diodes.
#
# ![Diodes](diodes.jpg 'Diodes')
#
# [Video: How does a diode work ?](https://www.youtube.com/watch?v=JNi6WY7WKAI)

# %% [markdown]
# ## Transistors
#
# What do you get when you put diodes back to back?
#
# You get the basic component that allows all computers to work: transistors.
#
# Transistors [Video](https://www.youtube.com/watch?v=7ukDKVHnac4)
#
# ### Bipolar Junction Transistor (BJT)
#
# A Bipolar Junction Transistor is a 3-terminal device whose level of conductivity can be controlled with a small amount of current. It is made with three layers of semiconductor: N-P-N, or P-N-P. It’s terminals are called: Base, Collector and Emitter.
#
# ![Bipolar Junction Transistor](BJT.jpg 'Bipolar Junction Transistor')
#
# ----
#
# Bipolar Junction Transistors, or BJTs for short, can be modelled with two diodes as shown in the following figures:
#
# BJT model with two diodes, structure and symbol. The arrow in the emitter indicates the direction of the current when the device is conducting.
#
# ![Bipolar Junction Transistor](BJT1.jpg)
#
# In BJTs, a small current in the base controls the amount of current that flows from the collector to the emitter (in NPN devices), or from the emitter to the collector (in PNP devices). Because of this property, it is common to use BJTs as current amplifiers.
#
# ### Field Effect Transistor (FET)
# Like BJTs, Field Effect Transistors are 3-terminal devices whose conductivity can be controlled with an external source. However, while BJTs are controlled with a small current, FETs are controlled with a small voltage. The three terminals are called: Gate, Source and Drain.
#
# The physical structure of a FET is quite different to the sandwich structure of BJTs. In FETs, the gate terminal is diffused into a substrate to form a channel (see figure below). Gate and substrate are of opposite charge: if the substrate is an N-type semiconductor, the gate is P-type, and vice-versa.
#
# ![Field Effect Transistor](FET.jpg 'Field Effect Transistor')
#
# Field Effect Transistors are very important because most of today’s electronic devices use them as their main building block. The reason is the exceedingly small amount of energy necessary to control their conductivity. When FETs are in saturation or cut-off state, they consume practically no power because no current flows through them. Power consumption only occurs during transitions between the saturation and cut-off states.
#
# A top of the range multi-core microprocessor contains several billion transistors, most switching thousands of millions of times per second. Think of how difficult it must be to manufacture such complex devices.
#
# ### Transistors as switches
#
# In the digital world, transistors are used as tiny switches that either conduct electric currents or not.
#
# When transistors are at their lowest level of resistance - that is, they are conducting the maximum amount of current - they are in a state called saturation.
#
# When transistors are at their highest level of resistance and a negligible amount of current is flowing through them, they are in the cut-off state.
#
# #### Circuit used to turn an NPN BJT into a switch
# This circuit depicts a transistor configured as a switch that operates a relay. The input – Vin, is a square wave and is allowed to activate the base of the transistor via a switch. When Vin is high, the transistor conducts. The relay is connected to the supply rail and the collector of the transistor, thus when the transistor conducts current flows through the relay, activating it. Note that the output is an inverted version of the input. This closes the load switch (part of the relay) allowing current to flow in the load circuit. The emitter is connected to ground and a voltage divider network is connected between Vin and ground.
#
# ![NPN BJT into a switch](NPNswitch.jpg 'NPN BJT into a switch')
#
# Circuit used to turn an NPN BJT into a switch. By closing and opening the ON/OFF switch, the BJT will go into saturation and cut-off correspondingly. It is important to note that the external voltage Vcc and the control voltage Vin are usually different. Transistors act as a sort of interface between components that operate at different voltages.
#
# #### Circuit to use a FET as a switch.
#
# The circuit illustrates a FET being used as a switch. A lamp is connected to the Drain and supply rail. The input – Vin, is a square wave and is allowed to activate the gate of the FET. When Vin is high, the FET conducts allowing current to flow through the lamp (on). The source is connected to ground. A voltage divider is connected to Vin and ground. Note that the output is an inverted version of the input.
#
# ![FET as a switch](FETswitch.jpg 'FET as a switch')
#
# Circuit to use a FET as a switch. In this example the voltage applied to the gate saturates or cuts-off the transistor. On saturation, the lamp will have a path to ground (0 Volts) and will produce light. On cut-off, the lamp will be effectively disconnected from ground and it will be turned off.
#
# In the previous two diagrams there is a flywheel diode connected in parallel with the load. Since a relay and an incandescent lamp are types of inductors, they will store energy as a magnetic field. Flywheel diodes offer a path to the current induced by the stored energy when the relay and lamp are turned off. Without this path, the spurious current would produce a spike of voltage that could damage other components.

# %% [markdown]
# ## Tinker with electronics in Tinkercad
#
# [Tinker with electronics - Transistor as Switch](IOT2x_04_TransistorAsSwitch.pdf)

# %% [markdown]
# ## Convertors
#
# Back to our problem of interfacing the analogue world with the digital world.
#
# We now know that computers can only deal with things that are represented as binary numbers. We also know that by grouping together enough bits and having notations for negative and floating-point numbers, there is practically nothing that computers cannot represent.
#
# To deal with analogue variables like temperature or pressure, all we need are devices that ‘translate’ between the analogue, infinite-valued world, and the binary, digital world of computers. These devices are called Analogue to Digital (ADC) and Digital to Analogue (DAC) Converters.
#
#
# [Video: Analogue and digital electronics - Converters
# ](https://www.youtube.com/watch?v=uEyCEUlxui4)
#
#
# ### Nyquist Theorem
#
# Nyquist theorem states that in order to be able to reproduce an analogue signal, the sampling rate needs to be at least two times faster than the signal’s highest frequency component. Voltage samples are compared against a reference voltage in the ADC (all ADCs need a reference voltage). The input voltage sample is then given a binary value in the range determined by the number of bits in the converter. The following formula provides the digital output (Out) for any given input voltage (Vin) in our 4-bit ADC example.
#
# $$ Out = \left ( \frac{2^4} { V_{ref}} \right) \times V_{in}$$
#
# The following graph shows the lineal relationship between the input voltage and the digital output. Note that for the digital number to accurately represent the temperature in the room, the relation between temperature and resistance must be a straight line.
#
# [Nyquist](Nyquist.jpg 'Nyquist theorem')
#
#
# n our example we used 4 bits for simplicity, however real ADCs use 10 to 20 bits; hence the steps between digital values represent very small variations in the analogue input.
#
# Once analogue values are converted to digital numbers, computers can then process them and make decisions based on the results. That will be the subject of a future module.
#
# To convert digital numbers back to analogue signals we use a DAC. The following figure shows the generic connection of a DAC.
#
# [Nyquist](Nyquist.jpg 'Nyquist theorem')
#
# $$ V_{Out} = \left ( \frac{V_{ref}}{2^4} \right ) \times In$$
#
# Note that $V_{out}$ can only take 16 possible values; hence this output is no longer analogue in the strict sense. The error induced by the rounding-off that takes place during the digital to analogue conversion is known as quantization error. To minimise quantization errors we can either increase the number of bits of the converter, or increase the sampling frequency, or both.
#
# Values in the output of a DAC are updated at a fixed rate similar to the sampling rate used in ADCs. A whole field called Digital Signal Processing  studies algorithms that can be applied to digitised signals.

# %%
def ADCout(n, Vref, Vin):
    Out = 2**n/Vref*Vin
    return round(Out)
print (f'ADCout is {ADCout(10, 10, 3.356)} and binary {ADCout(10, 10, 3.356):010b}')
# Out:
# ADCout is 344 and binary 0101011000

# %% [markdown]
# ## Electronics kits
#
# In this MicroMasters program we will be using:
#
# * [The Arduino Uno starter kit](https://store.arduino.cc/usa/arduino-starter-kit)
# * [Raspberry Pi](https://www.raspberrypi.org/products/#buy-now-modal)
# * [37 in 1 Sensor Kit for Arduino](http://www.openplatform.cc/index.php/home/index/details/apiid/79)
# from [here](https://www.jaycar.com.au/37-in-1-sensor-kit-for-arduino/p/XC4288)
#
# Electronics kits [video](https://www.youtube.com/watch?v=RwH2CyXsE5c)

# %% [markdown]
# ## Arduino and Tinkercad® for IoT
#
# [Video:](https://www.youtube.com/watch?v=74LQZxJs13w) Demo - Analogue to digital conversion in Tinkercad

# %% [markdown]
# # Module 2: End of the line things

# %% [markdown]
# ## Control Systems
#
# Common characteristics
# * They can perceive one or more aspects of the world; i.e. they can hear, see, feel, smell or taste something.
# * They can produce an action in the world; i.e. they can move, turn on, or activate something.
# * They have a bit of ‘intelligence’, that uses sensed information to make decisions about when and how to produce an action.
#
# ![Open-loop control system](Open-loop.jpg 'Open-loop control system')
#
# From a technical perspective, this diagram represents an open-loop control system. These are reactive systems because they control the world based on current information only.
#
# To add a bit more information to the decision-making process, actions on the world can also be monitored, as shown in the following diagram:
#
# ![Closed-loop control system](Closed-loop.jpg 'Closed-loop control system')
#
# The air conditioner in your house is probably a closed-loop system: You set the desired temperature and the air conditioner ‘knows’ when to start and stop operation in order to keep the room temperature as close to the desired value as possible.
#
# Control systems explain how IoT devices make decisions. But how exactly can a house ‘recognise’ faces and ‘open’ doors? The rest of this module will help you to answer this question. We will also be looking specifically at control systems in more detail in Module 4.

# %% [markdown]
# ## Sensors and Actuators
# 1. The combination of a transducer with its signal conditioner is called a __Sensor__
# 1. The combination of conditioning plus the element being controlled by the computer is called a __Actuator__
#
# A __transducer__ is a device that converts energy from one form to another. Usually a transducer converts a signal in one form of energy to a signal in another.
#
# ### Sensor functions and uses
#
# [Overview of sensors and actuators video](https://www.youtube.com/watch?v=lQrSRSt5B_o)
#
# ### Electronics kit and smart phone sensors
# [Video: Electronics kit sensors](https://www.youtube.com/watch?v=oNAhoASLysM)
#
# ### Phone Sensor
#
# ![Phone sensor](Phonesensor.jpg 'Phone sensor')
#
# ### Transducers
#
# [Video: Sensor functions and uses - Transducers](https://www.youtube.com/watch?v=WGVDqZF_RMc)
#
# Table showing typical IoT input and output transducer devices
#
# ![Transducer](Transducer.jpg 'Transducer')
# ![Terms](Terms.jpg 'Terms')

# %% [markdown]
# ## Sensors - What's out there and how do they work
#
# ["Sensor Terminology - National Instruments". 2018. Ni.Com. ](http://www.ni.com/white-paper/14860/en/)
#
# As we have seen, a sensor converts the physical environment (for example:  temperature, blood pressure, humidity, etc.) into a digital value or an analogue signal. There are a vast array of sensors available to utilise in our IoT projects. So many, in fact, that it’s hard to know where to start.
#
# It doesn’t really matter what we are sensing, as the approach and implementation of interfacing is similar. Sure, some attributes like sampling rate, processing requirements and signal levels change, but we can generally classify them according to their properties.
#
# These include:
# * Analog or Digital output signal
# * Transduction principles – the physical and chemical effects used to gain a reading
# * Material and Technology
# * Property
# * Application
#
#
# ----
#
#
# * __Sensitivity__
# The sensitivity of the sensor is defined as the slope of the output characteristic curve  or, more generally, the minimum input of physical parameter that will create a detectable output change.
#     * Sensitivity Error -
# The sensitivity error is a departure from the ideal slope of the characteristic curve. For example, the pressure transducer discussed above may have an actual sensitivity of 7.8 mV/V/mm Hg instead of 10 mV/V/mm Hg.
# * __Range__
# The range of the sensor is the maximum and minimum values of applied parameter that can be measured. For example, a given pressure sensor may have a range of -400 to +400 mm Hg.
#     * Dynamic Range
# The dynamic range is the total range of the sensor from minimum to maximum.
# * __Precision__
# The concept of precision refers to the degree of reproducibility of a measurement. In other words, if exactly the same value were measured a number of times, an ideal sensor would output exactly the same value every time. But real sensors output a range of values distributed in some manner relative to the actual correct value. For example, suppose a pressure of exactly 150 mm Hg is applied to a sensor. Even if the applied pressure never changes, the output values from the sensor will vary considerably. Some subtle problems arise in the matter of precision when the true value and the sensor's mean value are not within a certain distance of each other
# (e.g., the 1-s range of the normal distribution curve).
# * __Resolution__
# This specification is the smallest detectable incremental change of input parameter that can be detected in the output signal. Resolution can be expressed either as a proportion of the reading (or the full-scale reading) or in absolute terms.
# * __Accuracy__
# The accuracy of the sensor is the maximum difference that will exist between the actual value (which must be measured by a primary or good secondary standard) and the indicated value at the output of the sensor. Again, the accuracy can be expressed either as a percentage of full scale or in absolute terms.
# * __ Offset__
# The offset error of a transducer is defined as the output that will exist when it should be zero or, alternatively, the difference between the actual output value and the specified output value under some particular set of conditions.
# * __Linearity__
# The linearity of the transducer is an expression of the extent to which the actual measured curve of a sensor departs from the ideal curve. Figure 3 shows a somewhat exaggerated relationship between the ideal, or least squares fit, line and the actual measured or calibration line (Note in most cases, the static curve is used to determine linearity, and this may deviate somewhat from a dynamic linearity) Linearity is often specified in terms of percentage of nonlinearity, which is defined as:
# $$Nonlinearity(\%) = \frac{D_{in(max)}}{IN_{f.x}} \times 100$$
# where:
#
# * $Nonlinearity(\%)$ is the percentage of nonlinearity
# * $D_{in(max)} $ the maximum input deviation
# * $IN_{f.x}$ is the maximum, full-scale input
# * __Hysteresis__
# A transducer should be capable of following the changes of the input parameter regardless of which direction the change is made; hysteresis is the measure of this property.
# * __Response Time__
# Sensors do not change output state immediately when an input parameter change occurs. Rather, it will change to the new state over a period of time, called the response time. The response time can be defined as the time required for a sensor output to change from its previous state to a final settled value within a tolerance band of the correct new value.
# * __Dynamic Linearity__
# The dynamic linearity of the sensor is a measure of its ability to follow rapid changes in the input parameter.
#
# ----
#
# 1. __Environmental condition__: Usually has limits for temperature/humidity. These environmental factors can even have an effect on the readings and need to be factored into the calculations. E.g. accelerometers are sensitive to temperature and often have a temperature sensor incorporated into the device.
# 1. __Calibration__: Essential for most of the measuring devices, as the readings change with time.
# 1. Sensors can be classified based on __power__ or __energy supply requirement__:
#     * Active sensor: Requires a power supply. Examples include IMUs, LiDAR (Light detection and ranging), CCDs.
#     * Passive sensor: Examples include some RFID tags, thermistors, and temperature dependant resistors.
#
#
# Sensors can also fall into several categories based on their properties, or what they directly sense. Here are some links to further information that you may want to follow for your own particular area of interest.
#
#
# * [Temperature](https://www.electronics-tutorials.ws/io/io_3.html)Thermistors, thermocouples, resistive temperature detectors and many others.
# * [Pressure](https://www.electronics-tutorials.ws/io/io_3.html) Fibre optic, vacuum, elastic liquid-based manometers, linear variable differential transformer and electronic.
# * [Flow](https://www.engineeringtoolbox.com/flow-meters-d_493.html)
# * [Level Sensors](	https://www.engineersgarage.com/articles/WHAT-IS-LEVEL-SENSOR) Electromagnetic, differential pressure, positional displacement, thermal mass.
# * [Proximity and displacement](http://www.machinedesign.com/sensors/proximity-sensors-compared-inductive-capacitive-photoelectric-and-ultrasonic)  Linear variable differential transformer, photoelectric, capacitive, magnetic, ultrasonic.
# * [Biosensors](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4862100/) Resonant mirror, electrochemical, surface Plasmon resonance, Light addressable potentio-metric.
# * [CMOS](https://www.engineersgarage.com/articles/what-is-cmos-technology)  Charge coupled devices
# * [Gas and chemical:](https://www.google.com.au/url?sa=t&rct=j&q=&esrc=s&source=web&cd=7&ved=0ahUKEwjg8cTd5anaAhUIi7wKHUM9DK8QFgh0MAY&url=http%3A%2F%2Fwww.mdpi.com%2F2076-3298%2F4%2F1%2F21%2Fpdf&usg=AOvVaw1W3_IFKyESi_9bGe90Ajml)Semiconductor, infrared, conductance, electrochemical
# * [Inertial Measurement Units:](https://www.maximintegrated.com/en/app-notes/index.mvp/id/5830)Gyroscopes, accelerometers, magnetometers
# * [magnetometers.](https://www.engineersgarage.com/articles/magnetometer)
# * Others
# 	* [Moisture](http://blog.universalrfid.com/passive-moisture-sensors)
# 	* [humidity sensor](https://www.engineersgarage.com/articles/humidity-sensor)
# 	* [tilt sensor](https://www.engineersgarage.com/articles/what-is-tilt-sensor)
# 	* [force](https://www.tekscan.com/resources/whitepaper/load-cell-vs-force-sensor)
# 	* [viscosity](https://www.coleparmer.com/blog/2017/11/21/measure-viscosity/)
# * [List of sensors](https://en.wikipedia.org/wiki/List_of_sensors)
#
# ## Cases of 'indirect' sensor measurements
#
#  the idea that we can sense a great many things indirectly, from sensors not intended for that particular purpose, or by using multiple sensors to determine a seemingly unrelated property. This is common practice in the IoT and sensor world. Let’s look at two particular cases.
#
#  ### Water salinity
#
#  The level of dissolved salt in water is a critical measurement in many industries, particularly agriculture. However there isn’t a sensor available (at a reasonable cost, easy portability, etc.) that will directly measure NaCl (the type of salt we are interested in). So, the common approach is to approximate this value by measuring something that is a by-product of salinity levels: in this case, conductivity. As salinity increases, the impedance (resistance) decreases, as you can see in the table below:
#
# ![Water Salinity](WaterSalinity.jpg 'Water Salinity')
#
# ### Foot drop
#
# A more complex inference can be made when looking at the work done by Shiva Sharif in her research on foot drop, utilising IMUs (An inertial measurement unit).
#
# In this project, Shiva measures the acceleration and angular velocity of the foot and shin, in patients with a condition known as ‘foot drop’.
#
# When the foot acceleration and angular velocity is 0, and the shin IMU registers only gravity, we can infer that the foot is flat on the ground and the knee is straight. This gives us a reference point for all other measurements in the system, and allows for the calculation of the minimum and maximum deflection of the ankle joint… even though at no point did we directly measure an angle, or look to see if the patient’s foot is flat on the ground!
#
# ## Sensors in action
#
# [Video: Tinkercad® demo - sensor outputs](https://www.youtube.com/watch?v=wM5a1Kipwmw)

# %% [markdown]
# ## Talking to each other in the IoT
#
# ### Wired, local communication networks
#
# ![Wired, local communication networks](comms.jpg 'Wired, local communication networks')
#
# ### Communication protocols
#
# __Transmission__ depends on
# * The distance between the two end points;
# * The speed at which information needs to be moved; and
# * The safety of the information.
#
#
# ![wired communication standards](wiredcomm.jpg 'wired communication standards')
#
# 1. Not including ground.
# 1. Faster speeds available but not specified.
# 1. Dependent on capacitance of the wiring.
# 1. Software handshaking. Hardware handshaking requires additional pins.
# 1. Device count given in unit loads (UL). More devices are possible if fractional-UL receive.
# 1. Unidirectional communication only. Additional pins needed for each bidirectional communication.
# 1. Limitation based on bus capacitance and bit rate.
# 1. Additional pins needed for every slave if slave count is more than one.
#
# ----
#
#
# * Protocol
# 	* A set of rules and conventions that govern the exchange of information between devices (end points) in a communication network.
# * Synchronous versus asynchronous communication
# 	* Synchronous systems use a common clock that has to be transmitted on one of the wires. Asynchronous systems do not require transmitting the clock over the cable. In asynchronous communication, devices run their own clock, all at the same speed, and the data lines are used to achieve synchronisation.
# * Peer
# 	* Communication networks usually have levels or layers. Peers are each of the entities that exist on the same level of a network. For example, in the [TCP/IP](#TCP/IP) protocol (shown in the figure below), peers on every layer send messages only to their peers in the corresponding (same) layer. Devices from one layer are not peers with devices in a different layer.
# * Point-to-point, multi-drop, and multi-point
# 	* Devices use wires in different ways to connect to a network. The simplest connection is between two devices using a dedicated set of wires. This is called point-to-point communication. Sometimes many devices can share the same set of wires. This connection mode is usually referred to as a bus. In other networks, one master can connect to more than one slave using dedicated wires. This mode is called multi-point. Multi-drop refers to the number of devices connected to a bus, while multi-point refers to the number of one-to-one connections present in a network. The following figures show [examples of these configurations]().
# * Master/Slave networks
# 	* In some communication networks only one device, called the master, can talk to all the others, the slaves. Slaves cannot talk to each other directly; information transfers between slaves have to go through the master. In most transactions, the master initiates the exchange of information and determines when it finishes. To use the communication channel, slaves have to wait until the master grants them access, otherwise more than one slave could be transmitting information at the same, causing a collision.
# * Multi-master
# 	* Some master-slave protocols allow for more than one device to act as master. In these instances an arbiter decides which of the masters will take control of the channel and for how long.
# * Full-duplex
# 	*In a full-duplex channel, both end points can transmit information at the same time, usually over different wires.
# * Half-duplex
# 	* In a half-duplex channel, only one of the end-points can transmit information at one time, usually over one shared wire.
# * Maximum number of devices
# 	*,The number of devices that can be connected to a network depends on the physical properties of the cable (capacitance, resistance), or limits defined by the protocol; e.g. 8-bit addresses limit the number of devices to 256.
# * Maximum speed
# 	* The maximum speed of a communication channel depends on the processing speed of the end points and the physical properties of the medium (capacitance, inductance).
# * Maximum distance
# 	* The maximum length of a cable is determined by its physical properties (resistance, capacitance, and inductance) and the speed at which information is transmitted. High speeds imply transmitting high frequency signals over the wires. At high frequencies, normal wires behave like filters and antennae, deteriorating the quality of the transmitted signals.
#
#
# ##### TCP/IP
# ![TCP/IP](TCPIP.jpg 'TCP/IP')
#
# ##### Connections
# ![Connections](Connections.jpg 'Connections')
#
# ###RS-232
#
# This protocol was introduced in the 1960s to connect computers with modems. Nowadays communication occurs between computers, i.e. two DTE devices, hence connectors have to be carefully wired.
#
# It is worth noting that in the physical world RS-232 uses different sets of voltages to represent the 0s and 1s. The standard defines ‘1’ as a negative voltage between -3 and -25 Volts, and ‘0’ as a positive voltage between +3 and +25 Volts. Most PCs use -13 and +13 Volts to transmit signals. From the point of view of the protocols, 0s and 1s are just bits. Hence the timing diagrams below represent 1 as a high level, and 0 as a low level.
#
#
# ![RS232](RS232.jpg 'RS232')
#
# ### Handshake exchange and timing diagram
#
# 1. RTS (Request to Send) is put in the ON state by the DTE (Data Terminal Equipment/computer).
# 2. The DCE (Data Communications Equipment/modem) then puts the CTS (Clear to Send) line into the ON state.
# 3. The DTE then responds by placing the DTR (Data Terminal Ready) line into the ON state.
# 4. The DTR line remains on while data is being transmitted.
# ![RS232-Transmission](Transmission.jpg 'RS232-Transmission')
# T

# %% [markdown]
# ### I${}^2$C Inter-Integrated Circuit
#
# ![I2C](I2C.jpg 'I2C')
#
# I2C is a popular master-slave, multi-drop communication protocol used to exchange information between devices over very short distances, typically on the same printed circuit board. One of the attractive features of this bus is the low number of wires needed to interconnect devices. Only two lines are involved: the Serial Data line (SDA) and the Serial Clock line (SCL).
#
# * master-slave
# * multi-drop communication protocol
# * SDA - Serial Data line
# * SCL - Serial Clock line
# * I${}^2$C Inter-Integrated Circuit
#
# Note: You will find I2C also written as  I2C and also IIC. It is referred to as I squared C or I two C or I-I-C. It all comes from __'Inter-Integrated Circuit'__ as in communication between two integrated circuit boards.
#
# The following figure shows a network with one master and three slaves.
# MS.jpg
# ![Master Slave I2C](MS.jpg 'Master Slave I2C - Inter-Integrated Circuit')
#
# #### Clock mechanism
# In I2C communication, each device takes a designated role: either a __master__, or a __slave__. The master device pulses the clock for each transmitted bit, and the slave has to follow this speed. It is possible for a slave to hold down the clock line to pause communication until it is ready to continue. This mechanism is referred to as __clock stretching__ and ensures that a slave device has the ability to protect itself from being overwhelmed.
#
# #### Handshake exchange and timing diagram
# I²C defines the following basic types of messages, each of which begins with a START and ends with a STOP:
#
# * Single message where a master writes data to a slave;
# * Single message where a master reads data from a slave;
# * Combined messages, where a master issues at least two reads and/or writes to one or more slaves.
#
# * A HIGH to LOW transition on the SDA line while SCL is HIGH indicates a START condition. This is always initiated by the Master.
#
# * A LOW to HIGH transition on the SDA line while SCL is HIGH defines a STOP condition. See the following timing diagram.
#
#
# ![Timing I2C](I2CTiming.jpg 'Handshake exchange and timing diagram')
#
# In I2C information is transmitted one byte (8 bits) at a time, each followed by an acknowledge bit. If a slave is busy, it holds SCL LOW to force the master into a wait state. Data transfer continues when the slave releases SCL.
#
# Devices are identified with a 7-bit address, therefore, at least theoretically, up to 128 devices can be connected on the same bus. In practice however, some addresses are reserved for special purposes and only 112 are available. The following timing diagram shows the transmission of one byte.
#
# ![timing diagram shows the transmission of one byte I2C](Address.jpg 'Timing diagram shows the transmission of one byte')

# %% [markdown]
# ### SPI - Serial Peripheral Interface
#
# ![SPI](SPI.jpg 'The Serial Peripheral Interface (SPI)')
#
# The Serial Peripheral Interface (SPI) is
# * A synchronous, master-slave,
# * Full-duplex interface
# * Communicating between devices over short distances.
# * No specification for the protocol used between devices,
#     * message sizes and data rates can vary as required.
# * Acknowledgment of transmission by the receiver is not required either, but can be built in if it is useful.
#
# #### Connections
# SPIconnections
# ![SPI connections](SPIconnections.jpg 'SPI connections')
#
# * SCLK - Serial Clock. This is the clock signal being sent by the master to all slaves.
# * MOSI - Master Out, Slave In. This line is for sending data from master to a slave.
# * MISO - Master In, Slave Out. This line is for sending data from a slave to the master.
# * SS - Slave Select. There is a separate SS line between a master and each slave.
#
# #### Clock mechanism
# SPI is so versatile that every combination of the clock with the data lines can be adopted. These are called the SPI modes, and are shown in the following table.
#
# ![Clock Mechanism](ClockMechanism.jpg 'Clock Mechanism')
#
# #### Handshake exchange and timing diagram
# * SS - Slave Select. There is a separate SS line between a master and each slave. These lines are normally held high but are lowered to indicate when a data line should be written to or read from. Some manufacturers call this line Chip Select (CS)
# * MOSI - Master Out, Slave In. This line is for sending data from master to a slave. It's held high or low by the master before a clock edge to represent a '1' or '0'.
# * MISO - Master In, Slave Out. This line is for sending data from a slave to the master. It's held high or low by the slave before a clock edge to represent a '1' or '0'.
# * SCLK - Serial Clock. This is the clock signal being sent by the master to any slaves.
# The following timing diagram shows the sequence of signals involved in the transmission of 8 bits using the SPI mode ‘0’.
#
# ![Handshake exchange and timing diagram](SPItiming.jpg 'Handshake exchange and timing diagram')
#
# Devices will use the moment of either the rising or falling edge (low-to-high or high-to-low) of the clock line to read data, and use the opposite edge to make any changes to data on the line they are sending.
#
#
#
# #### Handshake exchange and timing diagram
# * SS - Slave Select. There is a separate SS line between a master and each slave. These lines are normally held high but are lowered to indicate when a data line should be written to or read from. Some manufacturers call this line Chip Select (CS)
# * MOSI - Master Out, Slave In. This line is for sending data from master to a slave. It's held high or low by the master before a clock edge to represent a '1' or '0'.
# * MISO - Master In, Slave Out. This line is for sending data from a slave to the master. It's held high or low by the slave before a clock edge to represent a '1' or '0'.
# * SCLK - Serial Clock. This is the clock signal being sent by the master to any slaves.
#
# The following timing diagram shows the sequence of signals involved in the transmission of 8 bits using the SPI mode ‘0’.
#
# ![Sequence of signals](SigSeq.jpg 'Sequence of signals')
#
# [Good description of transmission](https://blog.digilentinc.com/pmod-communication-serial-peripheral-interface-in-detail/)

# %% [markdown]
# ### Tinkering with communication protocols
#
# ![tinkering with communication protocols](ProtocolsArd.jpg 'Tinkering with communication protocols')
# [SPI bus pdf](05_SPI_Bus.pdf)

# %% [markdown]
# ### Sensor communication
#
# * [Sensor communication video](https://www.youtube.com/watch?v=azGIxEemeHY)

# %% [markdown]
# # Module3: Intermediary devices

# %% [markdown]
# ## Microcontrollers and microprocessors
#
# Most IoT systems utilise microcontroller units (MCUs) to collect data and transfer it to the processing units through the Internet. The advantages of using MCUs include:
#
# * They are relatively simple, as MCUs do not require an operating system to function and are easy to interface with external components such as sensors.
# * A MCU is usually sufficient to provide processing power and functionality in most IoT systems, thus making them economically viable for IoT applications.
# * Due to their simplicity, MCUs are less vulnerable to security attacks.
#
# A microprocessor is a micro version of our computers, hence the name ‘microprocessor’.
#
# We can see that generally, if an application requires a form of Operating System, a microprocessor is normally used. A good example is our smartphones, which often use ARM microprocessors.
#
# ### Microcontrollers vs microprocessors
#
# Microprocessors can be thought of as more advanced embedded systems than microcontrollers.  The main differences between a microprocessor and a microcontroller are:
#
# * A microcontroller is 'all in one': the processor, RAM, and IO are all on the one chip - as such, you cannot (for instance) increase the amount of RAM available or the number of IO ports. The controlling bus is internal and not available to the board designer.
# * A microprocessor generally does not have on-chip RAM, ROM, and few GPIO pins. It usually uses its pins as a bus to interface with RAM, ROM, serial ports, digital and analogue IO, etc. As such, it is expandable at the board level.
#
# Here are some examples of microcontrollers and microprocessors.
# ![Microcontroller](Microcontroller.jpg 'Microcontroller')
#
# [Video What is a Microcontroller?](https://www.youtube.com/watch?v=jKT4H0bstH8)
#
# ![Microcontroller](Microcontroller2.jpg 'Microcontroller')

# %% [markdown]
# ## Selecting a microplatform
#
# ### Microcontroller or microprocessor?
# ![Microcontroller or Microprocess](comms2.jpg 'Microcontroller or Microprocess')
#
#
# The first choice you need to make when designing an IoT solution is obviously whether to use a **Microcontroller or microprocessor**. In many cases this simply comes down to asking the question: *__Do I need an Operating System?__*
#
# When they are used, operating systems for IoT hardware are often categorised into two groups:
# * End devices
#     * End devices, or nodes, are often small and low power (both in energy and processing).
# * Gateways
#     * Gateways often control communication to the Cloud, or handle significant processing themselves.
#
# ----
#
# [Froehlich, Andrew. 2016. ‘8 IoT Operating Systems Powering the Future’. InformationWeek.com published by UBM](https://www.informationweek.com/iot/8-iot-operating-systems-powering-the-future/d/d-id/1324464)
#
# * _Embedded operating system_ used interchangeably with _Real-time operating system (RTOS)_
# * True RTOS IoT devices demand data be processed without buffering delays.
# * The benefits of an RTOS include the ability
#     * to multitask,
#     * to schedule and prioritize tasks,
#     * to manage the sharing of resources among multiple tasks.
#     * These operating systems are commonly used in more
#         * sophisticated aviation,
#         * industrial,
#         * healthcare IoT devices.
#
#
#
# *  Unlike PCs and mobile devices, there's a wide variety of commercial and open source operating systems powering the IoT. Here are eight leading contenders and the best use-cases for them.
#     1. __RIOT OS__
#     RIOT OS is an open source community project that has been ongoing since 2008. RIOT is capable of running on a [variety of platforms](http://www.riot-os.org/#usage)
#  including embedded devices and PCs (and a large number of the most popular sensor/actuator boards), and has an easy-to-use API. The OS is well known for its ability to be efficient in terms of power usage and resource requirements.
#     1. ¨__Windows 10 For IoT Microsoft's  __
#      Latest embedded OS is known as [Windows 10 for IoT](https://www.microsoft.com/en-us/WindowsForBusiness/windows-iot)  Under this umbrella, there are three subset operating systems available, depending on your needs. First is Windows 10 for IoT Mobile, which supports the ARM architecture. Next is Windows 10 for IoT Core, which supports Raspberry Pi and Intel Atom. Last, you have Windows 10 for IoT Enterprise -- more or less full-blown Windows 10 Enterprise, but restricted to running a single application.
#      Because Windows 10 for IoT is so new, it obviously lags behind many others in terms of user base and experienced developers. That said, the OS has tremendous potential -- especially if you want to develop apps in-house. Ultimately, those comfortable programming for Windows using Visual Studio and Azure IoT services will gravitate toward the suite of Windows 10 for IoT options.
#     1. __WindRiver VxWorks__
#     Probably the most popular commercial RTOS used today is WindRiver's VxWorks. It provides a robust OS that's highly scalable. VxWorks also provides a great number of security features that are critical for IoT projects that demand them. VxWorks is very well-known in the industrial, medical, and aerospace fields because it is one of the few RTOS vendors that have met the necessary [__certification requirements__](http://windriver.com/products/vxworks/#certified_products) to be used in those industries.
#     1. __Google Brillo__
#     Last fall at the Google I/O conference, Google announced its intention to enter the embedded OS market by introducing [Brillo](https://developers.google.com/brillo/). The developer platform for an Android-based embedded OS is great for those who have extensive backgrounds programming Android apps. Brillo uses a communications protocol called Weave. This means that smart devices don't necessarily have to have embedded Android as their OS -- they only have to have the ability to communicate using Weave. This opens the door to a lot more vendors incorporating Weave in their IoT products -- ultimately making them Brillo-compatible.
#     1. __ARM Mbed OS__
#     ARM is developing its own open source embedded OS called [mbed OS](https://www.mbed.com/en/development/software/mbed-os/). Since it's being developed by ARM, that's the only architecture supported. That said, the OS is expected to make a splash in the smart-home and wearable-device IoT segments. The OS differs from many other embedded operating systems because it's single-threaded -- as opposed to multi-threaded. ARM says it feels this is necessary for it to be able to run on the smallest and lowest-power devices out there. If physical size and battery life are critical, the IoT device may end up running on the mbed OS.
#     1. __Embedded Apple iOS And OS X__
#     While Apple has yet to play a significant role in today's IoT market, it certainly is expected to do so very soon. Up to this point, Apple has adopted variants of its iOS platform and created IoT devices such as Apple TV, CarPlay (with the help of BlackBerry QNX), and the Apple Watch.
# Moving forward, Apple is expected to continue its use of iOS -- and to modify OS X so that it runs leaner and more efficiently on IoT endpoints. Developers use tools such as the recently released [HomeKit](https://developer.apple.com/homekit/) -- a framework used to create apps to control home automation devices.
#     1. __Nucleus RTOS__
#     Nucleus RTOS is an embedded OS developed by Mentor Graphics. The company claims the software is currently running on more than 3 billion devices -- which is an impressive install base. The OS has robust support for [various embedded architectures](https://www.mentor.com/embedded-software/nucleus/processor-support) and is popular in industry verticals such as automotive, healthcare, utilities, industrial, and consumer electronics.
#     1. __Green Hills Integrity__
#     Yet another longstanding commercial RTOS solution is Green Hills' Integrity. It fiercely competes in the aerospace/defense, automotive, industrial, and medical verticals. The company is also continuing to be popular in the consumer-focused IoT market thanks to its long-standing popularity and reputation for performance, security, and reliability.
#
# Unlike with PCs, tablets, and smartphones, there likely won't be a short list of operating systems that dominate the entire IoT market. Instead, we're going to have to deal with dozens of popular choices that have specific pros and cons. This list of eight operating systems shows the wide variety of choices and where they are likely to be used.

# %% [markdown]
# ### Microcontroller or microprocessor? continued
#
# From now on, let’s refer to them both as a ‘micro’ unless we need to differentiate
#
#
# One of the main constraints of an IoT microcontroller or microprocessor is their __power consumption__.
#
# Other key aspects to consider when selecting a micro.
# * __Power consumption__
# Most IoT devices will be placed in the field running on a small battery. We would like the devices to run for weeks, days or even years on a single battery.
# * __Connectivity options__
# For example; Bluetooth, LoRa, 802.11 Choosing the IoT connectivity comes with its own set of choices, dependent mostly on power and range required.
# * __Development boards and kits__
# Many IoT development boards are prototyping solutions that [feature][] low-power processors and support various programming environments such as ‘C’, Python, Scratch, etc. These platforms are generally used to collect sensor data using [firmware] and transfer it to an on-site or cloud-based server.
# There are more powerful hardware prototyping platforms based on microcomputers, such as the [Raspberry Pi] and [BeagleBoard]. Such microcontrollers are enhanced with multiple core processors, may run an operating system, and support multiple types of [peripherals].
#
# ----
#
# When looking to develop a new IoT solution, prototypes of both hardware and software are implemented and refined through testing and product evaluation/feedback. What you choose will depend on:
# * the requirements of your project, and
# * your test results.
#
# Utilising off-the-shelf components can, in many cases, speed up the development process. As mentioned previously, there are many kits available and these can ‘jump start’ the development of rapid prototyping solutions, without the requirement of designing and producing custom-printed circuit boards (PCBs) and other components.
#
#
# [feature]:https://r-stylelab.com/company/blog/iot/iot-prototyping-3-reasons-to-use-off-the-shelf-components
# [firmware]:https://www.lifewire.com/what-is-firmware-2625881
# [Raspberry Pi]:https://www.raspberrypi.org/
# [BeagleBoard]:http://beagleboard.org/
# [peripherals]:https://www.computerhope.com/jargon/p/peripher.htm

# %% [markdown]
# ### High-level capabilities
#
# __IoT device specifications and characteristics__
#
# It is necessary to understand the underlying specifications of these devices, so as to evaluate and compare the characteristics of new devices as they become available.
#
# We can characterise IoT devices in terms of these high-level capabilities, including:
# * Power management
# * Sensors and actuators
# * Processing capability
# * Connectivity
#
# ### Power management
#
# * Power management is a critical concern for most IoT devices.
#     * Many are wearable
#     * installed in remote or inaccessible areas,
#     * run for long periods of time without maintenance
#         * including solar powered and [energy scavenging devices].
#
# One major constraint on power is not just the micro itself, but the __communications protocols implemented__ on the platform.
#
# Several aspects impact a device’s power requirements, including:
# * the clock rate of the CPU
# * number of processor cores
# * included peripherals (USB, Bluetooth, Ethernet ports)
# * processor load
# * supply voltage levels
#
# ![Microcontroller or Microprocess](micros.jpg 'Microcontroller or Microprocess')
#
# If you connect, for example, a camera module, the current required increases by around 250mA whenever the camera is in use. Sensors and actuators usually require power to operate, so the power consumption of the device as a whole also increases as you increase the number of components that are attached to the pins.
#
# [energy scavenging devices]:https://www.idtechex.com/research/reports/energy_harvesting_and_storage_for_electronic_devices_2010_2020_000243.asp

# %% [markdown]
# ### Sensors and actuators
#
# __Sensors__
#
# * __Data Acquisition__ (DAQ) is the process of measuring real-world conditions and converting these measurements into digital readings at fixed-time intervals (the data sample rate).
# * __Signal conditioning__ to filter usable data from the signals (i.e. remove noise) and scale raw sensor readings
# * __Resolution of the sensor__ and the required accuracy of our solution must be considered
#     * The __resolution__ of a sensor represents the smallest amount of change that the sensor can reliably read, and is related to the size of the numeric value that is used to represent raw sensor readings.
#
# As an example, consider if we want to measure the temperature of a solution in a chemical process to within 0.1 degrees Celsius.
#
# * If we use an analogue temperature sensor with a range of 0-100 degrees, we would require a 10 bit ADC to meet our requirements for accuracy.
# * 10 bits of resolution can represent a numeric value between 0 and 1023.
# * Bits are binary, so 10 bits provides 210, or 1024 possible values.
# * 100 degrees divided by 1024 ‘increments’ equals 0.098 degrees accuracy.
# * Therefore our development board would require an ADC of at least 10 bits resolution.
#
# In practical systems, sensors are affected by electrical noise, which usually requires us to build in a higher resolution than the minimum illustrated here.
#
#
# __Actuators__
#
# While sensors convert an environmental variable (temperature, humidity, etc.) into an electrical signal, output devices or actuators convert an electrical signal to a physical action. Output devices include LEDs, speakers, screens, and actuators such as motors or solenoids that move or control things in the physical world.
#
# When designing a system, we need to consider the ports necessary to drive these devices.
#
# For example, if we wish to move a servo motor to indicate the temperature read in our chemical reaction above, we must ensure that our development platform has a [Pulse Width Modulated] (PWM) pin.
#
# [Pulse Width Modulated]:https://www.electricaleasy.com/2015/01/how-does-servo-motor-work.html

# %% [markdown]
# ### Processing capability
#
# IoT devices capture, process, analyse and transform sensor data and/or interact with the environment via actuators and displays. To do so, they require processing and data storage capabilities. There are two main approaches to how, and more importantly, where we process our data:
#
# 1. Transmit the data to other devices, gateway devices, or cloud services or apps for aggregation and analysis.
# 1. Process the data locally in the IoT device (or perhaps on the gateway device).
#
# * The ‘Cloud’ based solution is to transmit possibly large volumes of data to a cloud server or data center for analysis.
# * The ‘Edge’ approach involves performing data analysis at the edges of a network where the data is captured, rather than in a centralised or Cloud location. Data can be analysed in real-time on the devices themselves, or on a nearby gateway device that the IoT devices are immediately connected to.
#
# * Processing data at the Edge provides an opportunity to aggregate and filter the data as it is collected, with only the most salient data being transmitted to the cloud.
# * Processing data at the Edge has the advantage of reducing the required network bandwidth at the cost of requiring a significantly more powerful processor within the IoT device.
# To determine the processor and memory requirements for our IoT device is a complex matter. It is very dependent on how much processing is done at the Edge, how complex the filtering and signal conditioning performed on the data is, and the rate at which we read the data.
#
# The amount of memory that is available, and the specifications of the processor (including the clock speed and number of cores), determine the rate at which data can be processed by the device. The capacity of the non-volatile flash memory, used to store data until it can be transmitted, determines how much data can be stored on the device.
#
# Devices performing Edge processing will require substantially more processing capabilities than devices that perform only basic data processing, like validating, normalising, scaling, or data conversion.

# %% [markdown]
# ### Connectivity
#
# Our microcontroller needs to talk to our sensors and actuators and also connect to the Internet, either directly or via a gateway/concentrator.
#
# Solutions may use:
#
# * __Wireless__ links, e.g. 802.11 WiFi, Bluetooth, Low Power Wide Area Network (LPWAN), LoRa and SigFox; or
# * __Wired links__ , e.g. SPI, I2C, Ethernet, RS232.
#
# __Wireless__ has the flexibility of being mobile (such as on cows moving around in the field), however, power consumption, restricted range and (comparatively) low data rates and throughput are a limitation with these technologies.
#
# __Wired__ technologies overcome some of the limitations of wireless, in particular the data rates and power efficiency, but can require significant infrastructure to be installed. Wired technologies are well suited to stationary devices such as smart housing and industrial manufacturing lines.

# %% [markdown]
# ### Prototyping boards
#
# [SoCs][] bundle a number of capabilities onto a single chip, including:
#
# * data processing
# * storage
# * networking
#
# [SoCs][] offer many advantages, including their low cost and the incorporation of a range of subsystems such as Graphic Processors (GPUs) and I/O ports (USB, DACs/ADCs, etc.).
#
# * [Video: Tour of the Raspberry Pi board](https://www.youtube.com/watch?v=qXK6Jf3vNak)
# * [Video: Tour of the Arduino Uno board](https://www.youtube.com/watch?v=sY6wC6OG2S4)
#
# [SoCs]:http://www.ubergizmo.com/what-is/system-on-a-chip/

# %% [markdown]
# ### Microcontroller and MicroComputer development boards
#
#
# __Microcontroller development boards__
#
# Microcontrollers contain a processor (often more than one - multicore), random access memory (RAM), and electrically erasable programmable read-only memory (EEPROM) for storing the custom programs that run on the microcontroller.
#
# Development boards are PCBs (printed circuit boards) with additional circuitry to support the microcontroller, to make it more convenient to prototype with and program the chip.
#
# ![Microcontroller](Arduino.jpg 'Microcontroller')
#
# __MicroComputer development boards__
#
# As with microcontroller development boards, these contain one or more processor cores, RAM, and some static storage such as an SD Card, USB flash drive, or hard drive (usually a solid state drive – SSD). However, in most cases they are much more powerful with a faster CPU, greater RAM, and a variety of I/O devices, such as USB, Ethernet, WiFi, and HDMI for screens, built-in.
#
# ![Microprocess](Pi.jpg 'Microprocess')
#
# Often also called ‘single board computers’, they also generally run an operating system, allowing an wide selection of development tools to be used. There are many different operating systems available. The most popular are those based on Linux.
#
# *__Be aware that these devices tend to have limited  GPIO  , often do not include ADCs or DACs, and consume significantly more power.__*
#
#
# [Slant. 2018. “What are the best single-board computers?” Slant Community](https://www.slant.co/topics/1629/~single-board-computers)

# %% [markdown]
# ### Selecting a micro
#
# * [Empty PDF for selection criteria of Micros](IoT2x_3.2MicroPlatform.pdf)
# * [Completed PDF for selection criteria of Micros](IoT2x_3.2MicroPlatform1.pdf)
#
#
# * [PJRC Electronic Projects](https://www.pjrc.com/teensy/teensy31.html)
# * [Arduino](https://www.arduino.cc/)
# * [Intel UP Squared Grove](https://software.intel.com/en-us/iot/hardware/up-squared-grove-dev-kit)
# * [Raspberry Pi](https://raspberry.piaustralia.com.au/raspberry-pi-boards/)
# * [BeagleBone Black](https://beagleboard.org/black)

# %% [markdown]
# ### Understanding 'bits' in micros
#
# [Video:Understanding 'bits' in micros](https://www.youtube.com/watch?v=_SkpnG571z8)

# %% [markdown]
# ### Do I need an Operating System?
#
# __Things to consider when choosing an embedded OS__
#
# * Memory Footprint
# This refers to the RAM requirement to run the OS. As IoT devices are constrained, we need to select an OS that will fit and is minimal in size, i.e. footprint. The OS should have low memory, power, and processing requirements.
# * Security
# OS has the ability to be secure by offering communication encryption, a secure bootloader, and code protection.
# * Modularity / Compatibility
# An OS consists of a kernel (core) that performs the basic requirements and isolates the software from the specifics of the hardware. All other features (e.g. USB support) should be modular and included only as necessary (see footprint). This kernel is often ported to other hardware platforms and can thus ease migration to newer or more powerful end devices as needed.
# * Support and Reliability
# IoT devices are often installed in remote locations and are expected to run for years without rebooting. For security and bug fixes, the OS should be well supported by either the vendor or a well-established open source community. In some cases, certifications and compliance to regulations is required. Some examples include:
#     * [DO-178B for avionics systems](https://en.wikipedia.org/wiki/DO-178B)
#     * [IEC 61508 for industrial control systems ](http://www.iec.ch/functionalsafety/)
#     * [ISO 62304 for medical devices](https://en.wikipedia.org/wiki/IEC_62304)
#     * SIL3/SIL4 IEC for transportation and nuclear systems
#
# (IoT2x_3.2OperatingSystem.pdf)
#
# ![Operating Systems](OpSys.jpg 'Operating Systems')
# ![Operating Systems](OpSys2.jpg 'Operating Systems')

# %% [markdown]
# ### Programming and selecting a 'language'
#
# __Overview of common languages for IoT__
# * Arduinos have great libraries and support for the C language.
# * Raspberry Pi are well suited to Python (but as they run Linux, they support many, many, languages).
# * The C language is powerful, efficient and very popular in constrained devices (limited memory/processing power) but is rather cryptic and difficult to use well. C Works at a ‘low level’ meaning it interacts well with the hardware and I/O.
# * Java is another popular language, and is cross platform (meaning you can transfer the code from one platform to another without too much modification). It has a version specifically for embedded systems (IoT): [Java SE Embedded](http://www.oracle.com/technetwork/java/embedded/embedded-se/learnmore/index.html).
# * Python is a scripting language, which unlike C does not require compiling. It is the preferred language for use on the Raspberry Pi, and is easy to learn with support from a large, helpful community.
# * Other small boards, such as the [Espruino](http://www.espruino.com/), utilise JavaScript (not to be confused with Java), another interpreted language like Python. JavaScript is easy to learn, and well adapted to web services, but perhaps not the most efficient language to use in computationally or I/O intensive applications.
#
# Article on programming languages for IoT
# * Wayner, Peter. N.D. [The top 6 programming languages for IoT projects](https://techbeacon.com/top-6-programming-languages-iot-projects) TechBeacon,

# %% [markdown]
# ##  Sensor communication

# %% [markdown]
# ### Sensor Communication
#
# SensorCommunication.jpg
# ![Sensor Communication](SensorCommunication.jpg 'SensorCommunication')
#
# What are appropriate communication protocols that should be adopted for micros to communicate with sensors.
#
# __Serial communication protocol__ is the common protocol used for microcontrollers’ communications. It involves the process of transmitting a series of digital pulses between sender and receiver on specified data rate, and is generally divided into __synchronous__ and __asynchronous__ categories.
#
# ![Protocols](protocols.jpg 'Protocols')
#
# ### Asynchronous serial communication
#
# In asynchronous serial communication, transmitter and receiver manually agree on the data rate, and each manage the timing independently with no common clock. That means the data rate for the transmitter sending pulses __is the same__ as data rate for the receiver listening for the pulses.
#
# The transmitter and receiver are required to __agree on some parameters__ to establish the asynchronous communication, including;
#
# * data rate
# * voltage level corresponding to 1 bit or 0 bit
# * signal voltage level interpretation;
#     * whether high voltage=1 and low voltage=0, or
#     * high voltage=0 and low voltage=1, for inverted signals.
#
# One example is the transmission between two devices at a data rate of 9600 bps (baud rate).
#
# 1. Both transmitter and receiver must agree on the voltage level interpretation corresponding to 1 bit and 0 bit;
# 1. Both ends are required to have a common ground connection to measure voltage with the same reference point;
# 1. A wire connection for the transmission from sender to receiver; and
# 1. A wire connection for the transmission from receiver to sender.
#
# When communication is established between the two devices with the agreed data rate (9600 bps for this example), the receiver reads the voltage constantly on the receiving wire and interprets it every $\frac{1}{9600}$th of a second.
#
# Generally, in most microcontrollers the high voltage is either +5V or +3.3V representing the 1 bit, and low voltage is 0V representing 0 bit. At the end of the data transmission, the receiver end is able to rebuild the original message by using the interpreted bits from voltage level.
#
# ----
#
# <center>
# __Asynchronous communication is suitable for connecting microcontrollers that can manage the time signal independently of each other, using their internal lock.__
# </center>
#
# ----
#
# The two most popular asynchronous serial communications are __RS-232__ and __USB__.
#
# |      |USB   |RS-232   |
# | :--- | :--- | :------ |
# |Method of Communication |full stack, master/slave communication|  point to point simple communication using only three wires to transmit data as bits|
# |Point of difference|faster speed and lower voltage usage|is more immune to electromagnetic interference (EMI)|
# |Maximum cable length|3 to 5 metres|   15 metres|
# |Used when / for |faster communication with simple implementation, such as Arduino board to PC|simple point to point connection, such as communication between Arduino board to other serial devices.|
#
# ### Synchronous serial communication
#
# ![Synchronous serial communication](MS.jpg 'Synchronous serial communication')
#
# In synchronous serial communication, a clocking system manages the synchronisation between the transmitter and receiver. The clock is either embedded as part of the data frame, or a separate clock wire manages the timing during transmission .
#
# All devices in the communication line share the same clock data, and with every clock pulse one bit moves in the line; therefore the clocking system directs devices regarding when to listen to the coming bits and when to discard them.
#
# ----
#
# <center>
# __This type of communication is used for simpler devices with no internal clock crystal
# and few memory registers.__
# </center>
#
# ----
#
# The two most common synchronous serial communications are
# * Inter-Integrated Circuit (I2C) and
# * Serial Peripheral Interface (SPI).
#
# ||I2C|SPI|
# |:--- |:--- |:--- |
# |Number of wires| Two wires|   Three or four wires|
# |Data rate|   Slow - 100kHz for original standard, 400kHz more recent standard |   Higher data rate, 10MHz or more, full duplex communication|
# |Power |  High  |  Low |
# |Overhead when handling point to point applications|  More overhead|   Less overhead|
# |Multiple devices |   Multiple devices on the same bus without additional select signal lines through in-communication device addressing|  Requires additional signal lines to manage multiple devices on the same bus|
# |Acknowledgement mechanism to confirm receipt of data  |  Has acknowledgement mechanism  | Does not have acknowledgement mechanism|
# |Reliability |One failed slave device can stop the transmission in the bus  |  Slave devices are connected by separate connections|
# |Built-in addressing schema  |Built-in addressing scheme and straightforward | Lack of built-in addressing schema|
# |Implementation cost| Cheaper |More expensive|
# |Number of master devices on the bus |Multiple |   One|
# |Noise |  Less susceptible to noise |  More susceptible to noise|
# |Data transmission distance | Greater distance with low data rate |Short distance|
# |Official specification | With official specifications (created by Philips) |  No official specifications (component dependent) and several protocol variations exist|
# |Application type  |  On-board devices that are accessed on an occasional basis  | Data streams applications|
#
# The differences between I2C and SPI clarify the selection options for each application, depending on its requirements. According to the distinctions between I2C and SPI, it may be concluded that:
#
# * I2C is more suitable when there is a large number of peripherals and a high data rate is not required;
# * SPI is a good option for applications that require low power and high speed.
#
# __However, both serial communication protocols are considered to be stable and robust protocols for embedded applications.__
#
# An excellent tutorial on SparkFun, which illustrates the differences between using parallel and serial communication, and then asynchronous (minimum number of wires and I/O pins but more effort to transfer data and often slower) and synchronous (often faster but at least one extra wire) serial communication.
#
# * Jimb0. ND. [Serial Communication SparkFun electronics](https://learn.sparkfun.com/tutorials/serial-communication/all)
#
# To quote the tutorial:
#
# ----
# __The critical part is making sure that both devices on a serial bus are configured to use the exact same protocols.__
#
# ----
#
# There is also a [video][1] from SparkFun Electronics on this subject. [SparkFun According to Pete 9-17-12: Serial Communication Demystified][1]
#
# [1]:https://www.youtube.com/watch?v=JJZOTtwpAjA

# %% [markdown]
# ##  Connecting up the system
#
# ### Packet Tracer: Connecting sensors and micro-platforms
#
# [Connecting Devices in Packet Tracer](Connecting_Devices_in_Packet_Tracer.pdf)

# %% [markdown]
# ## System Communication

# %% [markdown]
# ### System communication
# [Burgess, Larry. 2015. “How Does Sensor Data Go From Device To Cloud?” ReadWrite](https://readwrite.com/2015/10/13/sensor-data-device-to-cloud/)
#
# __Sensor to Cloud communication protocols__
# 1. __Ethernet__
# A wired network is the traditional way of connecting devices to the Internet, and is practical for an environment with a wired connection to the Internet, such as a smart home system.
# 2. Wireless
# The diagram below illustrates the different types of wireless communications used by mobile technology, and how the communication is sent to the internet: via Bluetooth (BT), WiFi and Mobile. ![WireLess](WireLess.jpg "Wireless"). However, in most IoT scenarios, Ethernet technology is not sufficient and some kind of wireless communication must be implemented based on power consumption, data rate, coverage, and cost

# %% [markdown]
# ### How a wireless technology works
# [Bluetooth video](https://www.youtube.com/watch?v=TXmOpc5_PO8)
# * Bluetooth transfers data through low-power radio waves whose frequency
# ranges from 2.40 gigahertz to 2.485
# * Bluetooth devices come in three classes.
#     1. Class one devices are used for industrial applications and have a range of 100 meters.
# Devices like your mobile phone or Bluetooth headset
# are
#     1. Class two devices which have a range of 10 meters.
#     1. Class three devices have a range of about 1 meter and are rarely used.
# * Bluetooth, can connect seven devices to one device and form a network of your own called the __piconet__
# * Bluetooth uses something called the ISM (Industrial, Scientific, and Medical) radio frequency band
# for communicating with other devices.
# * Bluetooth device has a transmitting and a receiving antenna
#     * The file is transferred by the spread spectrum frequency hopping technique.
# That is, parts of the file are sent by small bursts of radio waves whose frequency can change up to 1600 times per second
# to avoid interference in crowded environments.
# * The new Bluetooth Smart technology uses as low as 0.01 watts to 0.5 watts
# Hence, using Bluetooth does not drain your phone's battery
#
#
# Bluetooth was developed by the telecommunications company, Ericsson,
# in 1994, and was initially called Short Link Radio Technology until 1997,
# when it got the name, Bluetooth.
#
# Bluetooth is called Bluetooth because it is named
# after the Danish King, __Harald Blatand__.
# This king had this unique ability to bring
# quarreling people or tribes with feuds into calmly talking to each other
# and thus, ending the argument.
# The literal translation of __Blatand__ is __Bluetooth__ and Bluetooth
# does exactly what Blatand did.
# It connects two non-connected devices.
# Even the symbol of Bluetooth has the initials of Harald Blatand in it.
# This is a unique H and the B is inscribed inside the H.
# And that was Bluetooth for you.
# If you learned something new, then give this video a like
# and subscribe for some more awesome science.

# %% [markdown]
# ### How a wireless technology works continued
#
# [Video: LoRaWAN: Extremely long range, low power wireless communication](https://www.youtube.com/watch?v=7n8t62anxIQ)

# %% [markdown]
# ### Wireless communication introduction
#
# Wireless communication standards and technology can be grouped based on the size of the network:
#
# ![Wireless communication standards](NetWork.jpg "Wireless communication standards")
#
# From smallest to largest networks, these are:
# * Personal Area Network (PAN) and Wireless Sensor Network (WSN);
# * Wireless Local Area Network (WLAN); and
# * Wireless Wide Area Network (WWAN).
#
# ### Personal Area Network (PAN) and Wireless Sensor Network (WSN)
#
# __Bluetooth__
#
# |Name|Bluetooth|
# |---|---|
# |Standard protocol is based on|   IEEE802.15.1|
# |Designed for|Wireless ad-hoc connectivity that operates in 2.4 GHz ISM,<br> With low power consumption, <br> M2M (can be used for microcontroller to microcontroller communication)|
# |Connection range|    short range, 1-100 metres|
# |Data rate  | 1Mbit/s|
# |Example |Wearable sensors transmitting data to a smart phone|
#
# __6LoWPAN__
#
# |Name|6LoWPAN|
# |---|---|
# |Standard protocol is based on|IEEE802.15.41|
# |Designed for|Extends the use of Internet Protocol for low power devices with limited processing capabilities in a Personal Area Network (PAN),<br>  <br> M2M (can be used for microcontroller to microcontroller communication)|
# |Connection range|10s (tens) of metres|
# |Data rate  | maximum data rate of 250kbps|
# |Example |smart meters in a small network|
#
# ![PAN](PAN.jpg "PAN")

# %% [markdown]
# ### Wireless Local Area Network (WLAN)
#
# __WiFi__
#
# |Name|WiFi|
# |---|---|
# |Standard protocol is based on|IEEE802.11|
# |Designed for|Extend the Ethernet communication for wireless devices in Local Area Network (LAN),<br>  Operates in 2.4GHz (ISM band) or 5GHz (U-NII band))|
# |Connection range|different coverage area depending on building structure or geographical area|
# |Data rate  | m54Mbps – 600Mbps|
# |Example |IEEE802.11 has two operation modes: Ad-Hoc and Infrastructure.<br> In Ad-Hoc mode, devices are directly connected to each other; and in Infrastructure mode, wireless clients (Stations, STA) are connected through the Access Points (AP), forming a Basic Service Set (BSS). The BSSs are associated together via a wired Distributed System (DS) to form Extended Service Set (ESS).|
#
# ![WDS](WDS.jpg "WDS")

# %% [markdown]
# ### Wireless Wide Area Network (WWAN)
#
# ![Wireless communication standards](WWAN.jpg "Wireless Wide Area Network (WWAN)")
#
# * Mobile Network
# Cellular networks are rapidly evolving, to improve their connectivity services for increasing demand on ubiquitous devices and high data rate transmission requirements.
#
# Evolution
#     * 1G, 2G, 3G, and 4G
#     * 5G in the near future.
#
# ![Evolution](evolution.jpg "Evolution")
#
#
# * __GPRS__
#
# |Name|General Packet Radio Services (GPRS) or 2.5G|
# |---|---|
# |Standard protocol is based on|a packet switching data transmission standard|
# |Designed for|Mobile network and an extension to GSM (Global System for Mobile Communications)|
# |Connection range|Kilometres (depends on terrain)|
# |Data rate  | 64 -114 Kbps|
#
# * __LTE (Long Term Evolution)__
#     * LTE is based on Universal Mobile Telecommunication System (UMTS) and GSM network technologies.
#     * LTE is a 3G cellular network system that supports high data transmission rate for multimedia applications.
#
# |Name|LTE|
# |---|---|
# |Standard protocol is based on|3G cellular network system|
# |Designed for|&#9679; To increase the data rates available in 3G network technologies, Long Term Evolution (LTE) is designed as a series of 4G standards <br> &#9679; LTE architecture eliminates the need for RNC (Radio Network Controller) and uses Evolved Node B (eNB) that adds control and management functionalities to each base station|
# |Connection range|Kilometres (depends on terrain)|
# |Data rate  | 150Mbps (LTE-A with 1Gbps and LTE-A pro with 3Gbps)|

# %% [markdown]
# ### LPWAN - LoRa
#
# * Low Power Wide Area Network (LPWAN)
#     * Low power, low bit rate,
#     * Long range communication technology
#     * Designed for devices that are
#         * low power
#         * low processing devices such as sensors.
#     * The three types of LPWAN
#         * LoRa,
#         * Sigfox,
#         * Weightless.
#
# __LoRa__
# * LoRa is a spread spectrum modulation technology for low power and low cost receivers in IoT environments.
# * LoRaWANTM  is a LPWAN protocol introduced by LoRa Alliance, an open and non-profit organisation with more than 300 members who work together to define open global standards for IoT LPWAN.
#
# Security in LoRaWANTM is handled through network and application layers to make it a rather secure protocol. Devices, such as sensors, are connected to a network and application server through LoRa gateway, as per the diagram below.
#
# ![LPWAN - LoRa](LoRaWAN.jpg "LPWAN - LoRa")
#
# |Name|LoRa|
# |---|---|
# |Standard protocol is based on|Chirp spread spectrum (CSS) radio modulation technology|
# |Designed for|&#9679; For low power and low cost receivers in IoT environment <br> &#9679; Security in LoRaWANTM is handled through network and application layers to make it a rather secure protocol|
# |Connection range|Kilometres (greater than cellular)|
# |Data rate  | 0.3-50 Kbps|
#
# __LPWAN - Sigfox, Weightless__
# Sigfox Sigfox is a French company, that developed Sigfox technology.
#
# |Name|Sigfox|
# |---|---|
# |Standard protocol is based on|Ultra Narrow Band (UNB) ISM radio band|
# |Designed for|&#9679; Uses Ultra Narrow Band (UNB) to transmit information between low power devices operating at 868 MHz frequency band, that divides the spectrum into 400 of 100 Hz channels|
# |Connection range|30-50 km for rural areas, and 3-10 km for urban areas|
# |Data rate  | 100bps, with a limit of 140 messages per day for each end device|
#
#
# __Weightless__
# Weightless Special Interest Group (Weightless SIG) is a non-profit standards organisation that developed a LPWAN communication standard called Weightless. Weightless uses the low frequencies unused spectrum band with a high propagation signal and low output power. One example of a Weightless application is traffic sensors.
#
# There are three publications of weightless standards: Weightless-W, Weightless-N, and Weightless-P (further explained at the bottom of this page).
#
# |Name|Weightless|
# |---|---|
# |Standard protocol is based on|3 Weightless standards|
# |Designed for|&#9679; Uses the low frequencies unused spectrum band with high propagation signal and low output power|
# |Connection range|2-10k – see below|
# |Data rate  | Depends on standard  - see below (200bps – 10Mbps)|
#
# ![Weightless](WeightLess.jpg "Weightless")

# %% [markdown]
# ## Cloud, Fog, and Edge processing
# ### Cloud, Fog, and Edge processing
#
# [video Cloud, Fog, and Edge processing](https://www.youtube.com/watch?v=LX9o2xuEitI)
#
# ![Cloud, Fog, and Edge processing](CFE.jpg "Cloud, Fog, and Edge processing")
# ![Cloud, Fog, and Edge processing](CFE1.jpg "Cloud, Fog, and Edge processing")

# %% [markdown]
# ## References and further resources
#
# * [Arduino. ND. Arduino home page; Arduino: ](https://www.arduino.cc/)
# * [Arrow Electronics. 2016. “Understanding the Differences between 8 bit, 16bit, 32bit, and 64 bit - Arrow Tech Trivia” YouTube video 6:18 ](https://www.youtube.com/watch?v=_SkpnG571z8)
# * [Daware, Kiran. ND. “How Does a Servo Work? Electrical Easy.com; ](https://www.electricaleasy.com/2015/01/how-does-servo-motor-work.html)
# * [Froehlich, Andrew. 2016.”8 IoT Operating Systems Powering the Future” InformationWeek.com published by UBM, ](https://www.informationweek.com/iot/8-iot-operating-systems-powering-the-future/d/d-id/1324464)
# * [Harrop, Peter and Das, Raghu. 2010. “Energy Harvesting and Storage for Electronic Devices 2010-2020” IDTechEx, ](https://www.idtechex.com/research/reports/energy_harvesting_and_storage_for_electronic_devices_2010_2020_000243.asp?viewopt=desc)
# * [Jimb0. ND. “Serial Communication” SparkFun electronics. ](https://learn.sparkfun.com/tutorials/serial-communication/all)
# * [Madcoffee. 2018. “Arduino low power – how to run Atmega328P for a year on coin cell battery” Home automation community published byanteca GmbH,]( http://www.home-automation-community.com/arduino-low-power-how-to-run-atmega328p-for-a-year-on-coin-cell-battery/)
# * [Microchip Technology. 2010. “What is a Microcontroller” YouTube 6:47, ](https://youtu.be/jKT4H0bstH8)
# * [Pi Australia. ND. Raspberry Pi Boards. Little Bird Company. ](https://raspberry.piaustralia.com.au/raspberry-pi-boards/)
# * [Purves, Duncan. 2016. “Low Power Wireless Technologies and Standards for the Internet of Things. Connect Systems slide show on slideshare / LinkedIn; ](https://www.slideshare.net/DuncanPurves/low-power-wireless-technologies-and-standards-for-the-internet-of-things)
# * [Reps, Marco. 2017. “LoraWAN: Extremely long range, low power wireless communication” YouTube video 6:27, ](https://www.youtube.com/watch?v=7n8t62anxIQ)
# * [Science Everywhere. 2016 “Bluetooth Explained – All you need to know!” YouTube video, 2:50 ](https://www.youtube.com/watch?v=TXmOpc5_PO8)
# * [Servocity. ND. “How Does a Servo Work?” Servocity.com published by Robotzone, LLC,  ](https://www.servocity.com/how-does-a-servo-work)
# * [Slant.2018. “What are the best single-board computers?” Slant Community,  ](https://www.slant.co/topics/1629/~single-board-computers)
# * [The MagPi magazine. 2018. “Raspberry PI 3B+ specs and benchmarks” raspberrypi.org/magpi,  ](https://www.raspberrypi.org/magpi/raspberry-pi-specs-benchmarks/)

# %% [markdown]
# # Module 4 - Processes and Systems
#
# ## Processes and Systems
#
# ![Processes And Systems](ProcessesAndSystems.jpg "Processes And Systems")
# ![Coffee Pot](CoffePot.jpg "Coffee Pot")
#
# ### Closed-loop feedback systems
# The most common configuration is the closed-loop system. In this configuration, a proportion of the output of the system is fed back to the input and either added to (positive feedback) or subtracted from (negative feedback) the input. This results in the output of the system continually altering or updating the input with the current output conditions.
#
# ![Closed Loop](ClosedLoop.jpg "Closed-loop feedback systems")
#
# ### Open-loop control system
# Another less common configuration is that of the open-loop system. In these cases, the system does not monitor or measure the condition of its output signal. For that reason, it is also called a non-feedback system.
#
# [Closed Loop](OpenLoop.jpg "Open-Loop feedback systems")
#
# In IoT systems, open-loop may become more common as many devices are used only to ‘sense’. In these cases, there is no requirement for feedback at this point of data collection.
#
# For example, a device to monitor water quality may sense temperature, salinity, turbidity and oxygen levels, but performs no action locally. The data is transmitted back to a data centre where it is analysed, and some action may be taken (e.g. turn on a fountain for oxygenation). But even in this case, we can see there is an overall feedback path, but it is distributed.
#
# ### Open and closed loop advantages and disadvantages - error correction
#
# * Open-loop systems Disadvantage
#     * micro has no knowledge of the output (effect)
#     * cannot self-correct any errors when the preset input value drifts
#
# * Closed-loop systems
#     * Feedback from output to the input
#         * Reduce errors and
#         * Improve stability,
#         * required in IoT systems.
#     * Automatically achieve and maintain the desired output condition
#         * Comparing it with the actual condition.
#         * Generating an error signal
#             * Difference between the output and the reference input.
#
# The primary advantage of a closed-loop feedback control system is its ability to ¨¨reduce a system’s sensitivity__ to __external disturbances__.

# %% [markdown]
# ### Motor control
# * [Video: Demo - Open and closed loop motor control](https://www.youtube.com/watch?v=YRR_b-vEV8I)
#
# #### Robotic car - closed loop example
#
# [Video: Robotic car - closed loop example](https://www.youtube.com/watch?v=LfydfvHyikM)
#
# Closed-loop control systems have many advantages over open-loop systems. One advantage is the fact that the use of feedback makes the system response relatively insensitive to external disturbances, and internal variations in system parameters, such as temperature. It is thus possible to use relatively inaccurate and inexpensive components to obtain the accurate control of a given process or plant.
#
# However, __system stability__ can be a major problem, especially in badly designed closed loop systems, as they may try to __over-correct any errors__, which could cause the system to lose control and oscillate.
#
# To overcome this issue, let’s take a look at a more complex feedback system that is commonly used: __PID__.

# %% [markdown]
# ## PID
#
#
# 1. EEVacademy #6 - [PID Controllers Explained][] This one is very good
# 1. RCModelReviews. 2016. “[What PIDs do and how they do it][]” YouTube video 10:42
# 1. Douglas, Brian. 2012. “[PID Control – A brief introduction][]” YouTube video. 7:43
#
# [PID Control – A brief introduction]:https://www.youtube.com/watch?v=UR0hOmjaHp0
# [What PIDs do and how they do it]:https://www.youtube.com/watch?v=0vqWyramGy8
# [PID Controllers Explained]:https://youtu.be/VVOi2dbtxC0
#
# ### PID (proportional-integral-derivative controller)
#
# PID systems are found in a wide range of applications for
# * industrial process control,
# * sensor devices, and even
# * robotics.
#
# PID refers to the type of feedback path that this type of controller uses - in fact it uses three different paths, which is why a PID is also called a ‘three term controller’.
#
# Our previous examples were basically linear feedback systems, where the level of signal fed back to the input was directly proportional to the output of the system. This is, in fact, the first or
# * P part of the PID controller, proportional.
# * The I is integral, and
# * the D is derivative.
#
# These three modes are used in different combinations:
# * P – Sometimes used
# * PI - Most often used
# * PID – Sometimes used
# * PD – rare, but can be useful for controlling servomotors.
#
# ![proportional-integral-derivative controller](PID.jpg "proportional-integral-derivative controller")
#
# The idea of this algorithm revolves around manipulating the error. The error (used for feedback) is the difference between the:
#
# * __Process Variable__ (__PV__ - what we are trying to control, e.g. current temperature in our home);  and the
# * __Set Point__ (__SP__ - e.g. the temperature we would like our home to be)
#
# So, The __PV__ is subtracted from the __SP__ to create the error.
#
# * The error is simply multiplied by one, two, or all of the calculated P, I, and D actions (depending which are implemented);
# * Then the resulting combination of error values are added together and sent to the controller output;
# * If the PV and SP are the same, we don’t have to do anything (e.g. the temperature set in our home is the same as the temperature read by the sensors);
# * However, if there is a disparity between the SP and the PV, we have an error, and corrective action is needed.
#
# In delving further into how PID works, let’s consider the analogy of driving a car, and changing lanes on a freeway on a windy day. The driver is the ‘responsive’ controller in the process, as they are controlling the change in the car’s position.
#
# Below is a simplified diagram of a PID controller for this system.
# ![proportional-integral-derivative controller](PID1.jpg "proportional-integral-derivative controller")
#
# Notice how important closing the feedback loop is. If the feedback loop was removed (as in an open loop control system), it would be like steering the car with our eyes closed.
#
# As we saw in the previous house temperature example, the controller takes the both the PV and SP signals, and puts them through a black box to calculate a controller output. That controller output is then sent to an actuator, which moves to control the process.
#
# ### Proportional control
# Let’s isolate the proportional (P) part of our feedback loop in the diagram below.
# ![Proportional control](PID2.jpg "Proportional control")
#
# In __Proportional only__ mode, the controller simply multiplies the __Error__ by the __Proportional Gain__ (officially termed $K_p$) to get the controller output. The Proportional Gain is the setting that we tune to get our desired performance from a __P only__ controller.
#
# ![Proportional control](PID3.jpg "Proportional control")
# ![Proportional control](PID4.jpg "Proportional control")
#
# ### Adding Integral control
#
# Let’s start by using $K_P$ as our bias (ideal conditions and the rate we would like to change at), and add in another form of feedback – __the Integral__! Also known as the ‘automatic reset’, the Integral works simply by __resetting the bias of the gain until it’s zero again__.
#
# ![Integral control](PID5.jpg "Integral control")
# The combination of __Proportional__ and __Integral__ action seems to do a reasonably good job of controlling our system. In fact, PI controllers are probably the most common configuration
#
# ### Adding Derivative action
#
# The third type of action in PID control is the Derivative.
#
# * The effect of the derivative is to __counteract the overshoot__ caused by P and I
# * When the error is large, the P and the I will increase the controller output
# ** This controller response makes the error change quickly, which in turn causes the derivative to act more aggressively to counteract the P and the I
# * $K_D$ uses the rate of change of the error to calculate its ‘damping’ effect on the system.
#
#
# Like the Integral action, we need to be careful in choosing a Derivative value, but it is not as critical, as it may just stop us reaching our set point (or the correct place in the lane, in our car scenario).
#
# ![PID control](PID6.jpg "PID control")
#
# Let's compare the action of the most commonly used forms of PID control; P only, PI (most often used) and PID all together:
#
# ![PID control](PID6.jpg "PID control")
#
# __Note the PID control brings it to the set point faster. However, the D action is very hard to fine tune, so if the PI is good enough for what is needed, that will get used.__
#
#
# ### PID summary
#
# * The __P__roportional corrects __instances of error__;
# * The __I__ntegral corrects accumulation  of error; and
# * The __D__erivative corrects __present error versus error the last time it was checked__.

# %% [markdown]
# ## Design a System
# ### Defining the problem
#
# * What is the problem?
# * Who has this problem, and what do we know about them?
# * What are their concerns and needs?
# * How do they interact with their environment?
# * What causes the problem?
# * When does this problem occur?
# * Can you turn this problem into a question?
#
# [Design thinking: Questions for defining a problem](DesignThinking2.pdf)
#
# ### Researching solutions
# [Design thinking: Solution interrogation chart](DesignThinking.pdf)
